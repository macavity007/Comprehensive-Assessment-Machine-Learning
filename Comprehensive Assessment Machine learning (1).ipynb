# %%
#Factors affecting the Price of a Car

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
##Step 1: Data collection
"""Uploaded the data set in jupyter webstite and used the read_csv to read the dataset. """
# Out:
# 'Uploaded the data set in jupyter webstite and used the read_csv to read the dataset. '

# %%
Prd= pd.read_csv("CarPrice_Assignment.csv")

# %%
##Step 2: Read the dataset

# %%
Prd
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
Prd=Prd.drop('car_ID',axis=1)
Prd
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
Prd.head()
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %%
Prd.tail()
# Out:
#      symboling          CarName fueltype aspiration doornumber carbody  \
# 200         -1  volvo 145e (sw)      gas        std       four   sedan
# 201         -1      volvo 144ea      gas      turbo       four   sedan
# 202         -1      volvo 244dl      gas        std       four   sedan
# 203         -1        volvo 246   diesel      turbo       four   sedan
# 204         -1      volvo 264gl      gas      turbo       four   sedan
#
#     drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 200        rwd          front      109.1      188.8  ...         141
# 201        rwd          front      109.1      188.8  ...         141
# 202        rwd          front      109.1      188.8  ...         173
# 203        rwd          front      109.1      188.8  ...         145
# 204        rwd          front      109.1      188.8  ...         141
#
#      fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  \
# ...

# %%
##Step 3 :  Data Sanity Check

# %%
###To check the null value,datattype, number of columns and numbe rof values
Prd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
###To check the number of duplicate values
Dup = Prd.duplicated().sum()
if Dup >0:
    print("There is ",Dup,"Duplicate value")
else:
    print("No Duplicate value")
# Out:
# No Duplicate value

# %%
###To check the number of null values
Null_value=Prd.isnull().sum()
Null_value
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
###To show the number of object values in the dataset
Prd_cat = Prd.select_dtypes(include=['object'])

# Calculate and display the number of unique values for each category columns
for column in Prd_cat.columns:
    unique_count = Prd_cat[column].nunique()
    print(f"Column '{column}' has {unique_count} unique values.")
# Out:
# Column 'CarName' has 147 unique values.
# Column 'fueltype' has 2 unique values.
# Column 'aspiration' has 2 unique values.
# Column 'doornumber' has 2 unique values.
# Column 'carbody' has 5 unique values.
# Column 'drivewheel' has 3 unique values.
# Column 'enginelocation' has 2 unique values.
# Column 'enginetype' has 7 unique values.
# Column 'cylindernumber' has 7 unique values.
# Column 'fuelsystem' has 8 unique values.

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
Prd['CarName'] = label_encoder.fit_transform(Prd['CarName'])
Prd['fueltype'] = label_encoder.fit_transform(Prd['fueltype'])
Prd['aspiration'] = label_encoder.fit_transform(Prd['aspiration'])
Prd['doornumber'] = label_encoder.fit_transform(Prd['doornumber'])
Prd['carbody'] = label_encoder.fit_transform(Prd['carbody'])
Prd['drivewheel'] = label_encoder.fit_transform(Prd['drivewheel'])
Prd['enginelocation'] = label_encoder.fit_transform(Prd['enginelocation'])
Prd['fuelsystem'] = label_encoder.fit_transform(Prd['fuelsystem'])
Prd['enginetype'] = label_encoder.fit_transform(Prd['enginetype'])
Prd['cylindernumber'] = label_encoder.fit_transform(Prd['cylindernumber'])
Prd.head()
# Out:
#    symboling  CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          3        2         1           0           1        0           2
# 1          3        3         1           0           1        0           2
# 2          1        1         1           0           1        2           2
# 3          2        4         1           0           0        3           1
# 4          2        5         1           0           0        3           0
#
#    enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 0               0       88.6      168.8  ...         130           5
# 1               0       88.6      168.8  ...         130           5
# 2               0       94.5      171.2  ...         152           5
# 3               0       99.8      176.6  ...         109           5
# 4               0       99.4      176.6  ...         136           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
##Step 4: Exploratory Data Analysis(EDA)

# %%
### Perform the statistical analysis
Prd.describe().round(2)
# Out:
#        symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# count     205.00     205.00     205.00    205.00     205.00      205.00
# mean        0.83      98.76     174.05     65.91      53.72     2555.57
# std         1.25       6.02      12.34      2.15       2.44      520.68
# min        -2.00      86.60     141.10     60.30      47.80     1488.00
# 25%         0.00      94.50     166.30     64.10      52.00     2145.00
# 50%         1.00      97.00     173.20     65.50      54.10     2414.00
# 75%         2.00     102.40     183.10     66.90      55.50     2935.00
# max         3.00     120.90     208.10     72.30      59.80     4066.00
#
#        enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# count      205.00     205.00  205.00            205.00      205.00   205.00
# mean       126.91       3.33    3.26             10.14      104.12  5125.12
# std         41.64       0.27    0.31              3.97       39.54   476.99
# ...

# %%
Prd.describe(include="object") # Perform the statistical analysis on object column
# Out:
#               CarName fueltype aspiration doornumber carbody drivewheel  \
# count             205      205        205        205     205        205
# unique            147        2          2          2       5          3
# top     toyota corona      gas        std       four   sedan        fwd
# freq                6      185        168        115      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             205        205            205        205
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              202        148            159         94

# %%
###Distribution of numerical data

# %%
### draw histplot for every numerical column to see distrubution of data
for column in Prd.select_dtypes(include="number").columns:
    sns.histplot(data=Prd, x=column, kde=True)
    plt.title(f"Distribution of feature : {column}")
    plt.tight_layout()
    plt.show()
    print("\n")

# %%
###Distribution of categorical data

# %%
#draw count plot to see distribution of categorical data
for column in Prd.select_dtypes(include="object").columns:
    plt.figure(figsize=(8,5))
    sns.countplot(data=Prd, x=column, hue = column, palette="Set2")
    plt.title(f"Distribution of feature : {column}")
    plt.xticks(rotation=80)
    plt.tight_layout()
    plt.show()
    print("\n")

# %%
###Outlier Detection

# %%
# Outlier detection using boxplot
for column in Prd.select_dtypes(include="number").columns:
    if column == "price":
        continue
    sns.boxplot(data=Prd, x=column)
    plt.title(f"Boxplot of feature : {column}")
    plt.tight_layout()
    plt.show()
    print("\n")

# %%
# Check the relationship between x and y features using scatter plot
Prd.select_dtypes(include="number").columns # get numerical column names
# Out:
# Index(['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
correlation_matrix = Prd.select_dtypes(include="number").corr() # get correlation matrix
correlation_matrix
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(correlation_matrix, annot=True) # draw heatmap
plt.show()

# %%
ax = sns.pairplot(Prd[Prd.select_dtypes(exclude=['object']).columns])

# %%
#declare features vector and target
x = Prd.drop('price', axis=1)
y = Prd['price']

# %%
x_train , x_test , y_train , y_test  = train_test_split(x,y,test_size = 0.2)

# %%
print(x_train.shape , y_train.shape , x_test.shape ,y_test.shape)
# Out:
# (164, 24) (164,) (41, 24) (41,)

# %%
scale = StandardScaler() 
x = scale.fit_transform(x)

# %%
label = LabelEncoder()
y = label.fit_transform(y)

# %%
SVM_model = SVC()
LR_model = LogisticRegression(max_iter =10000)
DT_model = DecisionTreeClassifier()
RFC_model = RandomForestClassifier()
knc_model = KNeighborsClassifier()

SVM_model.fit(x_train, y_train)
LR_model.fit(x_train, y_train)
DT_model.fit(x_train, y_train)
RFC_model.fit(x_train, y_train)
knc_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
SVM_y_pred = SVM_model.predict(x_test)
LR_y_pred = LR_model.predict(x_test)
DT_y_pred = DT_model.predict(x_test)
RFC_y_pred = RFC_model.predict(x_test)
knc_y_pred = knc_model.predict(x_test)

# %%
#making prediction
y_pred = reg.predict(x_train)

# %%
#make prediciton
y_test_pred = reg.predict(x_test)

# %%
from sklearn.metrics import r2_score
print("r2_score = %s" % r2_score(y_test, y_test_pred))
# Out:
# r2_score = -68984.34517949451
